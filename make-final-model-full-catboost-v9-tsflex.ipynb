# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

import os

import pickle

from tqdm import tqdm

import lightgbm
import xgboost
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier 

import catboost
import gc
import random
random.seed(2233)

# for ens X
from sklearn.metrics import average_precision_score 
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.model_selection import StratifiedShuffleSplit

import matplotlib.pyplot as plt
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
MODEL = "catboost"
all_cols = ['target', 'Subject', 'precent_prograss_AccV', 'AccML__mean_crossings__w=5000', 'AccV__slope_sign_changes__w=5000', 'Visit', 'AccAP__slope_sign_changes__w=5000', 'AccML__maximum__w=5000', 'AccV__mean_crossings__w=5000', 'AccAP__kurt__w=5000', 'precent_prograss_AccAP', 'AccAP__mean_crossings__w=5000', 'AccAP__std__w=5000', 'AccML__std__w=5000', 'AccV__maximum__w=5000', 'AccML__slope_sign_changes__w=5000', 'AccAP__maximum__w=5000', 'id', 'AccAP__var__w=5000', 'AccV__std__w=5000', 'precent_prograss_Time', 'AccV__kurt__w=5000', 'AccV__var__w=5000', 'AccML__kurt__w=5000', 'AccAP__abs_energy__w=10000', 'AccML__abs_energy__w=10000', 'AccV__abs_energy__w=10000', 'AccAP__root_mean_square__w=10000', 'AccML__root_mean_square__w=10000', 'AccV__root_mean_square__w=10000']
parms = {'learning_rate': 0.010208491792291414, 'depth': 8, 'l2_leaf_reg': 1.6535621335085458, 'iterations': 505}

de_train = pd.read_pickle("/kaggle/input/make-data-tsflex-v9-de/train_de.pkl")[all_cols]
td_train = pd.read_pickle("/kaggle/input/make-data-v9-tsflex-td/train_td.pkl")[all_cols]

de_valid = pd.read_pickle("/kaggle/input/make-data-tsflex-v9-de/valid_de.pkl")[all_cols]
td_valid = pd.read_pickle("/kaggle/input/make-data-v9-tsflex-td/valid_td.pkl")[all_cols]

td_train["Valid"] = 1
td_train["Task"] = 1

td_valid["Valid"] = 1
td_valid["Task"] = 1

df_for_cv =  de_train.append(td_train).reset_index(drop=True)
df_for_sub = df_for_cv.append(de_valid).append(td_valid).reset_index(drop=True)

# folds_train_indexes_cv = pickle.load(open("/kaggle/input/v9-make-folds/folds_train_indexs_cv.pkl","rb"))
# folds_train_indexes_full = pickle.load(open("/kaggle/input/v9-make-folds/folds_train_indexs_full.pkl","rb"))

# folds_valid_indexes_cv = pickle.load(open("/kaggle/input/v9-make-folds/folds_valid_indexs_cv.pkl","rb"))
# folds_valid_indexes_full = pickle.load(open("/kaggle/input/v9-make-folds/folds_valid_indexs_full.pkl","rb"))

# %%
# # angry work-around
# def angry_workaround(df, indexs):
#     for fold in range(len(indexs)):
#         df.loc[indexs[fold][0], "target"] = 0    
#         df.loc[indexs[fold][1], "target"] = 1 
#         df.loc[indexs[fold][2], "target"] = 2    
#         df.loc[indexs[fold][3], "target"] = 3
#     return df


# df_for_cv = angry_workaround(df_for_cv, folds_train_indexes_cv)
# df_for_sub = angry_workaround(df_for_sub, folds_train_indexes_full)

# %%
# folds_train_indexs_full = pickle.load(open("/kaggle/input/v9-make-folds/folds_train_indexs_full.pkl", "rb"))
# train_ind = set([])
# for ele in folds_train_indexs_full:
#     for ind in ele:
#         train_ind.add(ind)
# relevant_ind = list(train_ind)

# df_for_sub = df_for_sub.loc[relevant_ind]

# %%
def get_model(parms= None, model_name="lgbm"):
    if model_name == "lgbm":
        if parms is None:
            model = lightgbm.LGBMClassifier()
        else:
            model = lightgbm.LGBMClassifier(**parms)
    elif model_name == "rf":
        if parms is None:
            model = RandomForestClassifier()
        else:
            model = RandomForestClassifier(**parms)     
            
    elif model_name == "xgboost":
        if parms is None:
            model = xgboost.XGBClassifier()
        else:
            model = xgboost.XGBClassifier(**parms) 
            
    elif model_name == "catboost":
        if parms is None:
            model = catboost.CatBoostClassifier()
        else:
            model = catboost.CatBoostClassifier(**parms) 
            
    elif model_name == "adaboost":
        if parms is None:
            model = AdaBoostClassifier()
        else:
            model = AdaBoostClassifier(**parms)
            
    return model

# %%
def fix_y(y):
    return y - 1 # (1,2,3) -> (0,1,2)

def fit_save(train_X,train_y, train_cols, cv_or_full,parms= None, model_name="lgbm"):
    no_train_cols = ["Time","Valid","Task",'Subject','file', 'id', 'target']    
    train_cols = [c for c in train_cols if c not in no_train_cols]
    
    model = get_model(parms, model_name)
    no_sh = False
    
    if set(train_y.unique()) == set([1,2,3]): # no SH
        train_y = fix_y(train_y)
        no_sh = True
    gc.collect()
    model.fit(train_X[train_cols], train_y)
    gc.collect()
    model_dict = {"model_name" : model_name,
                 "model": model,
                 "parms": parms,
                 "features": train_cols}
    pickle.dump(model_dict, open(f"model_dict_{model_name}_{cv_or_full}.pkl", "wb"))

# %%
#print(f"fit_save_{MODEL}_for_CV")
#fit_save(df_for_cv,df_for_cv["target"], train_cols=all_cols, parms= parms, model_name=MODEL, cv_or_full = "cv")

# print(f"Make_ENS_Xy_{MODEL}_for_CV")
# preds, gt = pipeline(df_for_cv, all_cols, folds=5, parms=parms, model_name=MODEL, cv_or_full = "cv")

# %%
print(f"fit_save_{MODEL}_for_submission")
fit_save(df_for_sub,df_for_sub["target"], train_cols=all_cols, parms= parms, model_name=MODEL, cv_or_full = "full")

# print(f"Make_ENS_Xy_{MODEL}_for_submission")
# preds, gt = pipeline(df_for_sub, all_cols, folds_total=folds_total, folds_start=folds_start,folds_end=folds_end,
#                      train_folds_list=folds_train_indexes_full , valid_folds_list= folds_valid_indexes_full, parms=parms, model_name=MODEL, cv_or_full = "full")
# Out:
# fit_save_catboost_for_submission
# 0:	learn: 1.3616235	total: 30.1s	remaining: 4h 12m 41s
# 1:	learn: 1.3378543	total: 58.2s	remaining: 4h 4m 7s
# 2:	learn: 1.3150035	total: 1m 26s	remaining: 4h 58s
# 3:	learn: 1.2929571	total: 1m 54s	remaining: 3h 58m 46s
# 4:	learn: 1.2716573	total: 2m 22s	remaining: 3h 57m 32s
# 5:	learn: 1.2510954	total: 2m 50s	remaining: 3h 56m 32s
# 6:	learn: 1.2311821	total: 3m 18s	remaining: 3h 55m 42s
# 7:	learn: 1.2119569	total: 3m 46s	remaining: 3h 54m 36s
# 127:	learn: 0.4132154	total: 1h 3s	remaining: 2h 56m 53s
# 128:	learn: 0.4110055	total: 1h 31s	remaining: 2h 56m 24s
# 129:	learn: 0.4087963	total: 1h 59s	remaining: 2h 55m 55s
# 130:	learn: 0.4066227	total: 1h 1m 27s	remaining: 2h 55m 28s
# 131:	learn: 0.4044407	total: 1h 1m 56s	remaining: 2h 55m
# 132:	learn: 0.4023079	total: 1h 2m 24s	remaining: 2h 54m 33s
# 133:	learn: 0.4002163	total: 1h 2m 52s	remaining: 2h 54m 6s
# 134:	learn: 0.3981021	total: 1h 3m 21s	remaining: 2h 53m 38s
# 135:	learn: 0.3960550	total: 1h 3m 49s	remaining: 2h 53m 11s
# 136:	learn: 0.3939783	total: 1h 4m 18s	remaining: 2h 52m 44s
# 137:	learn: 0.3919787	total: 1h 4m 46s	remaining: 2h 52m 16s
# 138:	learn: 0.3899859	total: 1h 5m 14s	remaining: 2h 51m 47s
# 139:	learn: 0.3880234	total: 1h 5m 42s	remaining: 2h 51m 19s
# 140:	learn: 0.3860576	total: 1h 6m 11s	remaining: 2h 50m 52s
# 141:	learn: 0.3841867	total: 1h 6m 39s	remaining: 2h 50m 24s
# 142:	learn: 0.3823202	total: 1h 7m 13s	remaining: 2h 50m 10s
# 143:	learn: 0.3804563	total: 1h 7m 47s	remaining: 2h 49m 56s
# 144:	learn: 0.3785822	total: 1h 8m 16s	remaining: 2h 49m 30s
# 145:	learn: 0.3767318	total: 1h 8m 44s	remaining: 2h 49m 1s
# 146:	learn: 0.3749374	total: 1h 9m 12s	remaining: 2h 48m 33s
# 147:	learn: 0.3731590	total: 1h 9m 41s	remaining: 2h 48m 6s
# 148:	learn: 0.3713849	total: 1h 10m 9s	remaining: 2h 47m 38s
# 149:	learn: 0.3696644	total: 1h 10m 37s	remaining: 2h 47m 9s
# 150:	learn: 0.3679268	total: 1h 11m 5s	remaining: 2h 46m 40s
# 151:	learn: 0.3662301	total: 1h 11m 33s	remaining: 2h 46m 11s
# 152:	learn: 0.3645478	total: 1h 12m 2s	remaining: 2h 45m 44s
# 153:	learn: 0.3628566	total: 1h 12m 31s	remaining: 2h 45m 17s
# 154:	learn: 0.3611927	total: 1h 12m 59s	remaining: 2h 44m 49s
# 155:	learn: 0.3595459	total: 1h 13m 28s	remaining: 2h 44m 21s
# 156:	learn: 0.3579244	total: 1h 13m 56s	remaining: 2h 43m 53s
# 157:	learn: 0.3563245	total: 1h 14m 24s	remaining: 2h 43m 25s
# 158:	learn: 0.3547697	total: 1h 14m 52s	remaining: 2h 42m 57s
# 159:	learn: 0.3532043	total: 1h 15m 20s	remaining: 2h 42m 28s
# 160:	learn: 0.3516512	total: 1h 15m 49s	remaining: 2h 41m 59s
# 161:	learn: 0.3501365	total: 1h 16m 17s	remaining: 2h 41m 31s
# 162:	learn: 0.3486361	total: 1h 16m 46s	remaining: 2h 41m 5s
# 163:	learn: 0.3471436	total: 1h 17m 15s	remaining: 2h 40m 37s
# 201:	learn: 0.3013672	total: 1h 35m 16s	remaining: 2h 22m 54s
# 202:	learn: 0.3003927	total: 1h 35m 44s	remaining: 2h 22m 25s
# 203:	learn: 0.2994153	total: 1h 36m 12s	remaining: 2h 21m 57s
# 204:	learn: 0.2983940	total: 1h 36m 41s	remaining: 2h 21m 30s
# 205:	learn: 0.2974255	total: 1h 37m 9s	remaining: 2h 21m 1s
# 206:	learn: 0.2964739	total: 1h 37m 37s	remaining: 2h 20m 33s
# 207:	learn: 0.2955321	total: 1h 38m 6s	remaining: 2h 20m 4s
# 208:	learn: 0.2945737	total: 1h 38m 35s	remaining: 2h 19m 38s
# 209:	learn: 0.2936629	total: 1h 39m 3s	remaining: 2h 19m 9s
# 210:	learn: 0.2927529	total: 1h 39m 32s	remaining: 2h 18m 41s
# 211:	learn: 0.2918834	total: 1h 40m	remaining: 2h 18m 13s
# 212:	learn: 0.2910424	total: 1h 40m 30s	remaining: 2h 17m 46s
# 213:	learn: 0.2901299	total: 1h 40m 58s	remaining: 2h 17m 18s
# 214:	learn: 0.2892772	total: 1h 41m 26s	remaining: 2h 16m 50s
# 215:	learn: 0.2884351	total: 1h 41m 54s	remaining: 2h 16m 21s
# 216:	learn: 0.2875942	total: 1h 42m 22s	remaining: 2h 15m 52s
# 217:	learn: 0.2867588	total: 1h 42m 51s	remaining: 2h 15m 24s
# 218:	learn: 0.2859275	total: 1h 43m 19s	remaining: 2h 14m 55s
# 219:	learn: 0.2850934	total: 1h 43m 47s	remaining: 2h 14m 27s
# 220:	learn: 0.2842882	total: 1h 44m 16s	remaining: 2h 13m 59s
# 221:	learn: 0.2834555	total: 1h 44m 44s	remaining: 2h 13m 31s
# 222:	learn: 0.2825747	total: 1h 45m 12s	remaining: 2h 13m 3s
# 223:	learn: 0.2817931	total: 1h 45m 41s	remaining: 2h 12m 35s
# 224:	learn: 0.2809716	total: 1h 46m 9s	remaining: 2h 12m 6s
# 225:	learn: 0.2802439	total: 1h 46m 37s	remaining: 2h 11m 37s
# 226:	learn: 0.2794282	total: 1h 47m 5s	remaining: 2h 11m 9s
# 227:	learn: 0.2786592	total: 1h 47m 33s	remaining: 2h 10m 40s
# 228:	learn: 0.2779267	total: 1h 48m 2s	remaining: 2h 10m 12s
# 229:	learn: 0.2771542	total: 1h 48m 30s	remaining: 2h 9m 44s
# 230:	learn: 0.2764263	total: 1h 48m 59s	remaining: 2h 9m 16s
# 231:	learn: 0.2756814	total: 1h 49m 27s	remaining: 2h 8m 48s
# 232:	learn: 0.2749022	total: 1h 49m 55s	remaining: 2h 8m 20s
# 233:	learn: 0.2741480	total: 1h 50m 24s	remaining: 2h 7m 51s
# 234:	learn: 0.2734059	total: 1h 50m 52s	remaining: 2h 7m 22s
# 235:	learn: 0.2726199	total: 1h 51m 20s	remaining: 2h 6m 54s
# 236:	learn: 0.2718975	total: 1h 51m 48s	remaining: 2h 6m 26s
# 237:	learn: 0.2712388	total: 1h 52m 16s	remaining: 2h 5m 57s
# 238:	learn: 0.2705582	total: 1h 52m 46s	remaining: 2h 5m 30s
# 239:	learn: 0.2698811	total: 1h 53m 14s	remaining: 2h 5m 2s
# 240:	learn: 0.2691993	total: 1h 53m 42s	remaining: 2h 4m 34s
# 241:	learn: 0.2685327	total: 1h 54m 11s	remaining: 2h 4m 5s
# 242:	learn: 0.2678155	total: 1h 54m 39s	remaining: 2h 3m 37s
# 243:	learn: 0.2671673	total: 1h 55m 7s	remaining: 2h 3m 8s
# 244:	learn: 0.2665808	total: 1h 55m 35s	remaining: 2h 2m 40s
# 245:	learn: 0.2659634	total: 1h 56m 4s	remaining: 2h 2m 12s
# 246:	learn: 0.2653147	total: 1h 56m 32s	remaining: 2h 1m 44s
# 247:	learn: 0.2646630	total: 1h 57m 1s	remaining: 2h 1m 16s
# 248:	learn: 0.2640416	total: 1h 57m 29s	remaining: 2h 48s
# 249:	learn: 0.2633842	total: 1h 57m 58s	remaining: 2h 19s
# 250:	learn: 0.2627023	total: 1h 58m 26s	remaining: 1h 59m 51s
# 251:	learn: 0.2620930	total: 1h 58m 55s	remaining: 1h 59m 23s
# 252:	learn: 0.2614668	total: 1h 59m 23s	remaining: 1h 58m 55s
# 253:	learn: 0.2608369	total: 1h 59m 51s	remaining: 1h 58m 26s
# 254:	learn: 0.2602434	total: 2h 19s	remaining: 1h 57m 58s
# 255:	learn: 0.2596771	total: 2h 48s	remaining: 1h 57m 30s
# 256:	learn: 0.2591045	total: 2h 1m 17s	remaining: 1h 57m 2s
# 257:	learn: 0.2585457	total: 2h 1m 45s	remaining: 1h 56m 34s
# 258:	learn: 0.2578939	total: 2h 2m 14s	remaining: 1h 56m 5s
# 259:	learn: 0.2572685	total: 2h 2m 42s	remaining: 1h 55m 37s
# 260:	learn: 0.2566688	total: 2h 3m 10s	remaining: 1h 55m 9s
# 261:	learn: 0.2560796	total: 2h 3m 38s	remaining: 1h 54m 40s
# 262:	learn: 0.2554835	total: 2h 4m 6s	remaining: 1h 54m 12s
# 263:	learn: 0.2548807	total: 2h 4m 35s	remaining: 1h 53m 43s
# 264:	learn: 0.2543131	total: 2h 5m 3s	remaining: 1h 53m 15s
# 265:	learn: 0.2537090	total: 2h 5m 32s	remaining: 1h 52m 47s
# 266:	learn: 0.2531034	total: 2h 6m	remaining: 1h 52m 19s
# 267:	learn: 0.2525075	total: 2h 6m 29s	remaining: 1h 51m 51s
# 268:	learn: 0.2519443	total: 2h 6m 57s	remaining: 1h 51m 23s
# 269:	learn: 0.2514100	total: 2h 7m 25s	remaining: 1h 50m 54s
# 270:	learn: 0.2508636	total: 2h 7m 54s	remaining: 1h 50m 26s
# 271:	learn: 0.2503679	total: 2h 8m 22s	remaining: 1h 49m 57s
# 272:	learn: 0.2498498	total: 2h 8m 50s	remaining: 1h 49m 29s
# 273:	learn: 0.2492753	total: 2h 9m 19s	remaining: 1h 49m 1s
# 274:	learn: 0.2487004	total: 2h 9m 47s	remaining: 1h 48m 33s
# 275:	learn: 0.2481732	total: 2h 10m 16s	remaining: 1h 48m 5s
# 276:	learn: 0.2476531	total: 2h 10m 44s	remaining: 1h 47m 36s
# 277:	learn: 0.2471800	total: 2h 11m 12s	remaining: 1h 47m 8s
# 278:	learn: 0.2466873	total: 2h 11m 41s	remaining: 1h 46m 40s
# 279:	learn: 0.2461643	total: 2h 12m 9s	remaining: 1h 46m 11s
# 280:	learn: 0.2456127	total: 2h 12m 37s	remaining: 1h 45m 43s
# 281:	learn: 0.2451638	total: 2h 13m 5s	remaining: 1h 45m 14s
# 282:	learn: 0.2446889	total: 2h 13m 34s	remaining: 1h 44m 46s
# 283:	learn: 0.2441965	total: 2h 14m 2s	remaining: 1h 44m 18s
# 284:	learn: 0.2437269	total: 2h 14m 30s	remaining: 1h 43m 50s
# 285:	learn: 0.2432559	total: 2h 14m 58s	remaining: 1h 43m 21s
# 286:	learn: 0.2427591	total: 2h 15m 27s	remaining: 1h 42m 53s
# 287:	learn: 0.2422740	total: 2h 15m 55s	remaining: 1h 42m 25s
# 288:	learn: 0.2418063	total: 2h 16m 24s	remaining: 1h 41m 56s
# 289:	learn: 0.2413057	total: 2h 16m 52s	remaining: 1h 41m 28s
# 290:	learn: 0.2408108	total: 2h 17m 20s	remaining: 1h 40m 59s
# 291:	learn: 0.2403360	total: 2h 17m 48s	remaining: 1h 40m 31s
# 292:	learn: 0.2398510	total: 2h 18m 17s	remaining: 1h 40m 3s
# 293:	learn: 0.2393998	total: 2h 18m 45s	remaining: 1h 39m 35s
# 294:	learn: 0.2389266	total: 2h 19m 13s	remaining: 1h 39m 6s
# 295:	learn: 0.2385027	total: 2h 19m 42s	remaining: 1h 38m 38s
# 296:	learn: 0.2380464	total: 2h 20m 10s	remaining: 1h 38m 10s
# 297:	learn: 0.2375990	total: 2h 20m 39s	remaining: 1h 37m 42s
# 298:	learn: 0.2371837	total: 2h 21m 7s	remaining: 1h 37m 13s
# 299:	learn: 0.2367325	total: 2h 21m 35s	remaining: 1h 36m 45s
# 300:	learn: 0.2362940	total: 2h 22m 4s	remaining: 1h 36m 17s
# 301:	learn: 0.2358692	total: 2h 22m 32s	remaining: 1h 35m 48s
# 302:	learn: 0.2355012	total: 2h 23m	remaining: 1h 35m 20s
# 303:	learn: 0.2350728	total: 2h 23m 29s	remaining: 1h 34m 52s
# 304:	learn: 0.2346626	total: 2h 23m 57s	remaining: 1h 34m 23s
# 305:	learn: 0.2342748	total: 2h 24m 25s	remaining: 1h 33m 55s
# 306:	learn: 0.2338742	total: 2h 24m 54s	remaining: 1h 33m 27s
# 307:	learn: 0.2334757	total: 2h 25m 22s	remaining: 1h 32m 58s
# 308:	learn: 0.2331070	total: 2h 25m 50s	remaining: 1h 32m 30s
# 309:	learn: 0.2326750	total: 2h 26m 18s	remaining: 1h 32m 2s
# 310:	learn: 0.2322452	total: 2h 26m 47s	remaining: 1h 31m 33s
# 311:	learn: 0.2318405	total: 2h 27m 15s	remaining: 1h 31m 5s
# 312:	learn: 0.2314096	total: 2h 27m 43s	remaining: 1h 30m 37s
# 313:	learn: 0.2310323	total: 2h 28m 12s	remaining: 1h 30m 8s
# 314:	learn: 0.2306423	total: 2h 28m 40s	remaining: 1h 29m 40s
# 315:	learn: 0.2302541	total: 2h 29m 8s	remaining: 1h 29m 12s
# 316:	learn: 0.2298931	total: 2h 29m 37s	remaining: 1h 28m 43s
# 317:	learn: 0.2295451	total: 2h 30m 5s	remaining: 1h 28m 15s
# 318:	learn: 0.2291654	total: 2h 30m 33s	remaining: 1h 27m 47s
# 319:	learn: 0.2288097	total: 2h 31m 1s	remaining: 1h 27m 18s
# 320:	learn: 0.2284774	total: 2h 31m 29s	remaining: 1h 26m 50s
# 321:	learn: 0.2280985	total: 2h 31m 57s	remaining: 1h 26m 21s
# 322:	learn: 0.2277638	total: 2h 32m 25s	remaining: 1h 25m 53s
# 323:	learn: 0.2274164	total: 2h 32m 54s	remaining: 1h 25m 25s
# 324:	learn: 0.2270645	total: 2h 33m 22s	remaining: 1h 24m 56s
# 325:	learn: 0.2267170	total: 2h 33m 49s	remaining: 1h 24m 27s
# 326:	learn: 0.2263168	total: 2h 34m 17s	remaining: 1h 23m 59s
# 327:	learn: 0.2259543	total: 2h 34m 45s	remaining: 1h 23m 31s
# 328:	learn: 0.2256097	total: 2h 35m 14s	remaining: 1h 23m 2s
# 329:	learn: 0.2252611	total: 2h 35m 42s	remaining: 1h 22m 34s
# 330:	learn: 0.2249317	total: 2h 36m 10s	remaining: 1h 22m 5s
# 331:	learn: 0.2245547	total: 2h 36m 38s	remaining: 1h 21m 37s
# 332:	learn: 0.2241866	total: 2h 37m 6s	remaining: 1h 21m 9s
# 333:	learn: 0.2238448	total: 2h 37m 34s	remaining: 1h 20m 40s
# 334:	learn: 0.2234618	total: 2h 38m 2s	remaining: 1h 20m 12s
# 335:	learn: 0.2231038	total: 2h 38m 30s	remaining: 1h 19m 43s
# 336:	learn: 0.2228242	total: 2h 38m 58s	remaining: 1h 19m 15s
# 337:	learn: 0.2225391	total: 2h 39m 27s	remaining: 1h 18m 47s
# 338:	learn: 0.2222480	total: 2h 39m 55s	remaining: 1h 18m 18s
# 339:	learn: 0.2219015	total: 2h 40m 23s	remaining: 1h 17m 50s
# 340:	learn: 0.2216233	total: 2h 40m 52s	remaining: 1h 17m 22s
# 341:	learn: 0.2213227	total: 2h 41m 20s	remaining: 1h 16m 53s
# 342:	learn: 0.2209597	total: 2h 41m 48s	remaining: 1h 16m 25s
# 343:	learn: 0.2206084	total: 2h 42m 16s	remaining: 1h 15m 56s
# 344:	learn: 0.2202588	total: 2h 42m 44s	remaining: 1h 15m 28s
# 345:	learn: 0.2199473	total: 2h 43m 12s	remaining: 1h 14m 59s
# 346:	learn: 0.2196515	total: 2h 43m 40s	remaining: 1h 14m 31s
# 347:	learn: 0.2193636	total: 2h 44m 8s	remaining: 1h 14m 3s
# 348:	learn: 0.2190373	total: 2h 44m 36s	remaining: 1h 13m 34s
# 349:	learn: 0.2187441	total: 2h 45m 5s	remaining: 1h 13m 6s
# 350:	learn: 0.2184490	total: 2h 45m 32s	remaining: 1h 12m 37s
# 351:	learn: 0.2181460	total: 2h 46m	remaining: 1h 12m 9s
# 352:	learn: 0.2178462	total: 2h 46m 28s	remaining: 1h 11m 40s
# 353:	learn: 0.2175577	total: 2h 46m 56s	remaining: 1h 11m 12s
# 354:	learn: 0.2173072	total: 2h 47m 24s	remaining: 1h 10m 44s
# 355:	learn: 0.2169741	total: 2h 47m 52s	remaining: 1h 10m 15s
# 356:	learn: 0.2166905	total: 2h 48m 21s	remaining: 1h 9m 47s
# 357:	learn: 0.2164456	total: 2h 48m 50s	remaining: 1h 9m 19s
# 358:	learn: 0.2161762	total: 2h 49m 18s	remaining: 1h 8m 51s
# 359:	learn: 0.2158808	total: 2h 49m 46s	remaining: 1h 8m 22s
# 360:	learn: 0.2156026	total: 2h 50m 14s	remaining: 1h 7m 54s
# 361:	learn: 0.2153047	total: 2h 50m 42s	remaining: 1h 7m 25s
# 362:	learn: 0.2150376	total: 2h 51m 10s	remaining: 1h 6m 57s
# 363:	learn: 0.2148012	total: 2h 51m 39s	remaining: 1h 6m 29s
# 364:	learn: 0.2145385	total: 2h 52m 7s	remaining: 1h 6m 1s
# 365:	learn: 0.2142712	total: 2h 52m 35s	remaining: 1h 5m 32s
# 366:	learn: 0.2140061	total: 2h 53m 3s	remaining: 1h 5m 4s
# 367:	learn: 0.2137700	total: 2h 53m 31s	remaining: 1h 4m 36s
# 368:	learn: 0.2134932	total: 2h 53m 59s	remaining: 1h 4m 7s
# 369:	learn: 0.2132108	total: 2h 54m 27s	remaining: 1h 3m 39s
# 370:	learn: 0.2129913	total: 2h 54m 55s	remaining: 1h 3m 11s
# 371:	learn: 0.2127404	total: 2h 55m 24s	remaining: 1h 2m 42s
# 372:	learn: 0.2124435	total: 2h 55m 52s	remaining: 1h 2m 14s
# 373:	learn: 0.2122023	total: 2h 56m 20s	remaining: 1h 1m 46s
# 374:	learn: 0.2119138	total: 2h 56m 49s	remaining: 1h 1m 18s
# 375:	learn: 0.2116882	total: 2h 57m 18s	remaining: 1h 49s
# 376:	learn: 0.2114706	total: 2h 57m 46s	remaining: 1h 21s
# 377:	learn: 0.2112020	total: 2h 58m 14s	remaining: 59m 53s
# 378:	learn: 0.2109661	total: 2h 58m 42s	remaining: 59m 24s
# 379:	learn: 0.2107582	total: 2h 59m 10s	remaining: 58m 56s
# 380:	learn: 0.2104801	total: 2h 59m 39s	remaining: 58m 28s
# 381:	learn: 0.2102519	total: 3h 7s	remaining: 57m 59s
# 382:	learn: 0.2100391	total: 3h 36s	remaining: 57m 31s
# 383:	learn: 0.2098584	total: 3h 1m 4s	remaining: 57m 3s
# 384:	learn: 0.2096408	total: 3h 1m 33s	remaining: 56m 35s
# 385:	learn: 0.2094176	total: 3h 2m 1s	remaining: 56m 7s
